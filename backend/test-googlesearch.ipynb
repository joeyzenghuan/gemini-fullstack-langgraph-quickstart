# %%
# 测试Google Search API和web_research功能
import os
import sys
from dotenv import load_dotenv
from google.genai import Client
import json
from pprint import pprint

# 添加项目根目录到路径
sys.path.append(os.path.join(os.getcwd(), 'src'))

# 加载环境变量
env_path = r'C:\GitRepo\gemini-fullstack-langgraph-quickstart\backend\.env'
load_dotenv(dotenv_path=env_path)

# 检查API密钥
print("GEMINI_API_KEY:", "已设置" if os.getenv("GEMINI_API_KEY") else "未设置")
print("AZURE_OPENAI_ENDPOINT:", os.getenv('AZURE_OPENAI_ENDPOINT'))

# 初始化Google Generative AI客户端
genai_client = Client(api_key=os.getenv("GEMINI_API_KEY"))
# Out:
# GEMINI_API_KEY: 已设置
# AZURE_OPENAI_ENDPOINT: https://jz-fdpo-swn.openai.azure.com/

# %%
# 导入所需的工具函数和提示模板
from agent.prompts import get_current_date, web_searcher_instructions
from agent.utils import get_citations, resolve_urls, insert_citation_markers

# 测试搜索查询
test_query = "最新的人工智能发展趋势"

# 格式化搜索提示
current_date = get_current_date()
formatted_prompt = web_searcher_instructions.format(
    current_date=current_date,
    research_topic=test_query,
)

print("=== 格式化的提示词 ===")
print(formatted_prompt)
print("\n" + "="*50 + "\n")
# Out:
# === 格式化的提示词 ===
# Conduct targeted Google Searches to gather the most recent, credible information on "最新的人工智能发展趋势" and synthesize it into a verifiable text artifact.
#
# Instructions:
# - Query should ensure that the most current information is gathered. The current date is June 05, 2025.
# - Conduct multiple, diverse searches to gather comprehensive information.
# - Consolidate key findings while meticulously tracking the source(s) for each specific piece of information.
# - The output should be a well-written summary or report based on your search findings.
# - Only include the information found in the search results, don't make up any information.
#
# Research Topic:
# 最新的人工智能发展趋势
#
#
# ==================================================

# %%
# $ test with no grounding tool
# 调用Google Search API
try:
    response_hello = genai_client.models.generate_content(
        model="gemini-2.0-flash-exp",  # 使用默认模型
        contents="hello",
        config={
            # "tools": [{"google_search": {}}],
            "temperature": 0,
        },
    )
    
    print("=== API调用成功! ===")
    print(f"响应状态: 成功")
    print(response_hello.text)
    
except Exception as e:
    print(f"API调用失败: {e}")
    response_hello = None
# Out:
# === API调用成功! ===
# 响应状态: 成功
# Hello! How can I help you today?

# %%
# $ test with no grounding tool
# 调用Google Search API
try:
    response_no_grounding = genai_client.models.generate_content(
        model="gemini-2.0-flash-exp",  # 使用默认模型
        contents=formatted_prompt,
        config={
            # "tools": [{"google_search": {}}],
            "temperature": 0,
        },
    )
    
    print("=== API调用成功! ===")
    print(f"响应状态: 成功")
    print(response_no_grounding.text)
    
except Exception as e:
    print(f"API调用失败: {e}")
    response_no_grounding = None
# Out:
# === API调用成功! ===
# 响应状态: 成功
# Okay, I will conduct targeted Google Searches to gather the most recent, credible information on "最新的人工智能发展趋势" (latest AI development trends) as of June 5, 2025, and synthesize it into a verifiable text artifact. I will focus on finding sources dated in 2025 or late 2024 to ensure the information is current.
#
# **Search Queries:**
#
# 1.  "最新的人工智能发展趋势 2025" (Latest AI development trends 2025)
# 2.  "人工智能发展趋势 2025" (AI development trends 2025)
# 3.  "未来人工智能发展方向 2025" (Future AI development direction 2025)
# 4.  "人工智能技术最新进展 2025" (Latest advances in AI technology 2025)
# 5.  "AI发展趋势报告 2025" (AI development trend report 2025)
# 6.  "中国人工智能发展趋势 2025" (China AI development trends 2025) - *Given the language, focusing on China is relevant.*
# 7.  "最新AI应用领域 2025" (Latest AI application areas 2025)
#
# **Expected Challenges:**
#
# *   Finding information *specifically* dated in 2025 will be difficult, as it's only June. I will prioritize late 2024 and early 2025 sources and extrapolate trends.
# *   Language barrier: I will need to translate and interpret Chinese sources accurately.
# *   Distinguishing hype from genuine trends. I will prioritize reports from reputable research institutions, industry analysts, and academic publications.
#
# **Synthesis Process:**
#
# I will read the search results, identify key trends, and note the source URL for each trend. I will then synthesize this information into a coherent report, citing each source.
#
# **Report:**
#
# After conducting the searches, here's a synthesized report on the latest AI development trends as of June 5, 2025, based on the (hypothetical) search results.
#
# **Latest AI Development Trends (June 5, 2025)**
#
# Based on recent reports and analyses, the following trends are shaping the AI landscape in 2025:
#
# 1.  **Hyper-Personalization Driven by AI:** A report by *CCID Consulting* (CCID Consulting, 2025) highlights the increasing use of AI to deliver hyper-personalized experiences across various sectors, including e-commerce, healthcare, and education. AI algorithms are now capable of analyzing vast amounts of user data to tailor products, services, and content to individual preferences with unprecedented accuracy.
#
# 2.  **Edge AI Dominance:** *Gartner's 2025 Hype Cycle for AI* (Gartner, 2025) indicates that Edge AI is moving beyond the "Peak of Inflated Expectations" and entering the "Slope of Enlightenment." This trend involves deploying AI models directly on edge devices (e.g., smartphones, IoT sensors, autonomous vehicles), reducing latency, improving privacy, and enabling real-time decision-making.
#
# 3.  **Generative AI's Continued Evolution:** Generative AI models continue to advance rapidly, as noted in a *Tencent Research Institute* whitepaper (Tencent Research Institute, 2025).  Beyond text and images, generative AI is now being used to create complex 3D models, design new materials, and even compose music with increasing sophistication.  Concerns around deepfakes and misinformation remain a key challenge.
#
# 4.  **AI-Powered Cybersecurity:**  With the increasing sophistication of cyber threats, AI is playing a crucial role in cybersecurity.  *Qihoo 360's 2025 Cybersecurity Report* (Qihoo 360, 2025) emphasizes the use of AI to detect and respond to cyberattacks in real-time, automate security tasks, and predict future threats.
#
# 5.  **AI for Sustainability:**  A *United Nations report on AI and Sustainable Development* (United Nations, 2025) highlights the growing use of AI to address environmental challenges, such as climate change, resource management, and pollution control. AI is being used to optimize energy consumption, improve agricultural practices, and monitor deforestation.
#
# 6.  **Quantum AI gaining traction:** While still in early stages, Quantum AI is starting to show promise. *Baidu Research's Quantum AI 2025 report* (Baidu Research, 2025) details the progress in developing quantum algorithms for machine learning, potentially leading to significant breakthroughs in areas such as drug discovery and materials science.
#
# 7.  **Explainable AI (XAI) becoming essential:** As AI systems become more complex, the need for transparency and explainability is growing.  *The AI Ethics Council's 2025 report* (AI Ethics Council, 2025) emphasizes the importance of XAI to build trust in AI systems, ensure fairness, and comply with regulations.
#
# **Sources (Hypothetical):**
#
# *   CCID Consulting, "2025 Report on Hyper-Personalization Trends in China," 2025.
# *   Gartner, "Hype Cycle for Artificial Intelligence, 2025," 2025.
# *   Tencent Research Institute, "Generative AI: The Next Frontier," 2025.
# *   Qihoo 360, "2025 Cybersecurity Report," 2025.
# *   United Nations, "AI for Sustainable Development: 2025 Update," 2025.
# *   Baidu Research, "Quantum AI 2025: Progress and Prospects," 2025.
# *   AI Ethics Council, "Explainable AI: A 2025 Perspective," 2025.
#
# **Disclaimer:**
#
# This report is based on hypothetical search results as of June 5, 2025. The specific findings and sources are illustrative and may not reflect actual future developments.  In a real-world scenario, I would provide the actual URLs and verifiable information from the search results.

# %%
# 调用Google Search API
try:
    response = genai_client.models.generate_content(
        model="gemini-2.0-flash-exp",  # 使用默认模型
        contents=formatted_prompt,
        config={
            "tools": [{"google_search": {}}],
            "temperature": 0,
        },
    )
    
    print("=== API调用成功! ===")
    print(f"响应状态: 成功")
    
except Exception as e:
    print(f"API调用失败: {e}")
    response = None
# Out:
# === API调用成功! ===
# 响应状态: 成功

# %%
# 查看原始响应内容
if response:
    print("=== 原始响应对象类型 ===")
    print(f"响应类型: {type(response)}")
    # print(f"响应属性: {dir(response)}")
    print("\n" + "="*50 + "\n")
    
    # 查看响应的主要内容
    print("=== 生成的文本内容 ===")
    print(response.text)
    print("\n" + "="*50 + "\n")
    
    # 查看候选结果
    print("=== 候选结果信息 ===")
    for i, candidate in enumerate(response.candidates):
        print(f"候选结果 {i+1}:")
        print(f"  - 内容: {candidate.content}")
        print(f"  - 安全评级: {candidate.safety_ratings}")
        if hasattr(candidate, 'grounding_metadata'):
            print(f"  - 有grounding_metadata: {candidate.grounding_metadata is not None}")
        print()
    print("="*50 + "\n")
# Out:
# === 原始响应对象类型 ===
# 响应类型: <class 'google.genai.types.GenerateContentResponse'>
#
# ==================================================
#
# === 生成的文本内容 ===
# 基于最新的研究和分析，以下是2025年人工智能发展的主要趋势：
#
# **1. 人工智能的可及性和更低的培训成本:**
# *   人工智能的普及正在改变模型的训练和部署方式。模型架构和硬件效率的提高大大降低了大规模人工智能系统的训练成本，使更多用户可以使用这些系统。 (Ultralytics)
# *   人工智能技术的普及促进了各行各业的创新，使初创企业和小型企业能够开发和部署曾经属于大型企业领域的人工智能解决方案。培训成本的降低也加快了迭代周期，使人工智能模型的实验和完善更加迅速。(Ultralytics)
#
# **2. 人工智能代理和人工通用智能（AGI）:**
# *   人工智能代理正变得越来越先进，为实现人工通用智能（AGI）架起了桥梁。与传统的人工智能系统专为狭窄的任务而设计不同，这些代理可以不断学习，适应动态环境，并根据实时数据做出独立决策。(Ultralytics)
# *   2025年，多代理系统，即多个人工智能代理合作实现复杂目标，有望变得更加突出。这些系统可以优化工作流程，产生洞察力，并协助各行各业做出决策。(Ultralytics)
#
# **3. 计算机视觉的进步:**
# *   视觉转换器（ViTs）、边缘人工智能和3D视觉等新方法正在推进实时感知和分析。这些技术为自动化、医疗保健、可持续发展和机器人技术带来了新的可能性，使计算机视觉比以往任何时候都更加高效和强大。(Ultralytics)
# *   自监督学习、视觉转换器和边缘人工智能等先进技术有望提升机器感知、分析和与世界交互的能力。这些创新将继续推动实时图像处理、物体检测和环境监测的发展，使人工智能驱动的视觉系统更高效、更易于在各行各业使用。(Ultralytics)
#
# **4. 边缘人工智能:**
# *   边缘计算的一个关键优势是它能够在云连接有限或不切实际的环境中实现实时决策。通过将边缘计算与人工智能驱动的视觉相结合，各行业可以实现更高的可扩展性、更快的响应速度和更强的安全性，使实时人工智能视觉成为2025年自动化的基石。(Ultralytics)
#
# **5. 道德和负责任的人工智能:**
# *   随着人工智能越来越多地参与决策过程，围绕偏见、隐私和责任的伦理问题变得越来越重要。人工智能模型需要确保公平、透明和符合法规，尤其是在医疗保健、金融和招聘等敏感行业。 (Ultralytics)
# *   2025年，预计会有更严格的法规，并更加强调负责任的人工智能，推动企业开发可解释和可审计的模型。积极采用道德人工智能框架的企业将赢得消费者的信任，满足合规要求，并确保人工智能应用的长期可持续性. (Ultralytics)
#
# **6. 多模态人工智能:**
#
# *   2025年多模态AI将成为企业采用AI的主要驱动力，助力改善客户体验，提高运营效率，开发新的商业模式。例如，多模态AI将广泛用于医疗领域，通过分析医疗记录、成像数据、基因组信息等推进个性化医疗；在零售、金融服务、制造业等领域的应用也将不断扩展。(新华网)
#
# **7. AI推理能力增强:**
#
# *   AI的逻辑推理能力在提升。OpenAI在2024年9月发布推理模型o1，并在12月迅速升级到o3版本，新模型在数学、编程、博士级科学问答等复杂问题上，表现出超越部分人类专家的水平。谷歌也在12月发布其最新推理模型“双子座2.0闪电思维”，专注于解决编程、数学及物理等领域的难题。(新华网)
#
# **8. 智能体普及和具身智能:**
#
# *   智能体的出现频率将越来越高。智能体指使用AI技术，能够自主感知环境、作出决策并执行行动的智能实体。业界普遍认为，这种智能体2025年将变得更加普及，且能处理更复杂的任务，将人类从一些重复且琐碎的工作中解放出来。(新华网)
# *   智能体还可结合物理实体，形成“具身智能”，如自动驾驶汽车、具身智能机器人等。美国特斯拉公司研发的人形机器人“擎天柱”已可在工厂行走、分拣电池，还能以接近人类的灵活度用单手稳稳接住迎面抛来的网球，有望在2025年实现小批量生产并投入使用。(新华网)
#
# **9. AI驱动的智能代理将改变工作形态:**
#
# *   预计到2025年，新一代AI 驱动的代理将能够处理更多任务，甚至可以代表用户来执行某些任务。(Microsoft Research)
#
# **10. 量子人工智能崭露头角:**
#
# *   量子人工智能仍处于起步阶段，但它已经在科技和研究界掀起了波澜。它结合了量子计算和人工智能，旨在解决传统人工智能无法高效处理的复杂问题。IBM 和谷歌等公司正在大力投资量子人工智能，显示出其改变医疗、金融和物流等行业的潜力。(Botpress)
#
# **11. AI安全治理体系持续完善:**
#
# *   模型能力提升与风险预防并重，AI安全治理体系持续完善。基础模型在自主决策上的持续进步带来了潜在的失控风险，如何引入新的技术监管方法，如何在人工监管上平衡行业发展和风险管控？(华尔街见闻)
#
# **12. AI对能源的需求大幅增长:**
#
# *   推理端算力需求大幅增长，基于云的人工智能系统需要消耗更多的能源，可持续发展日益紧迫。(中信建投)
#
# **13. 人工智能将发展为巨大的市场:**
#
# *   联合国的一份报告预测，到2033年，人工智能将发展成为价值4.8万亿美元的全球市场，规模相当于德国当前的经济总量。(UN News)
#
# **14. AI智能体规模应用的"拐点时刻":**
#
# *   2025年，AI领域的热议话题已经从大语言模型（LLMs）转向了AI智能体（AI Agent）。根据Gartner最新预测，企业软件中整合自主型AI的比例将从2024年的不足1%跃升至2028年的33%；同时，超过15%的日常工作决策将交由AI智能体自主完成。(IBM)
#
#
# ==================================================
#
# === 候选结果信息 ===
# 候选结果 1:
#   - 内容: parts=[Part(video_metadata=None, thought=None, inline_data=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, text='基于最新的研究和分析，以下是2025年人工智能发展的主要趋势：\n\n**1. 人工智能的可及性和更低的培训成本:**\n*   人工智能的普及正在改变模型的训练和部署方式。模型架构和硬件效率的提高大大降低了大规模人工智能系统的训练成本，使更多用户可以使用这些系统。 (Ultralytics)\n*   人工智能技术的普及促进了各行各业的创新，使初创企业和小型企业能够开发和部署曾经属于大型企业领域的人工智能解决方案。培训成本的降低也加快了迭代周期，使人工智能模型的实验和完善更加迅速。(Ultralytics)\n\n**2. 人工智能代理和人工通用智能（AGI）:**\n*   人工智能代理正变得越来越先进，为实现人工通用智能（AGI）架起了桥梁。与传统的人工智能系统专为狭窄的任务而设计不同，这些代理可以不断学习，适应动态环境，并根据实时数据做出独立决策。(Ultralytics)\n*   2025年，多代理系统，即多个人工智能代理合作实现复杂目标，有望变得更加突出。这些系统可以优化工作流程，产生洞察力，并协助各行各业做出决策。(Ultralytics)\n\n**3. 计算机视觉的进步:**\n*   视觉转换器（ViTs）、边缘人工智能和3D视觉等新方法正在推进实时感知和分析。这些技术为自动化、医疗保健、可持续发展和机器人技术带来了新的可能性，使计算机视觉比以往任何时候都更加高效和强大。(Ultralytics)\n*   自监督学习、视觉转换器和边缘人工智能等先进技术有望提升机器感知、分析和与世界交互的能力。这些创新将继续推动实时图像处理、物体检测和环境监测的发展，使人工智能驱动的视觉系统更高效、更易于在各行各业使用。(Ultralytics)\n\n**4. 边缘人工智能:**\n*   边缘计算的一个关键优势是它能够在云连接有限或不切实际的环境中实现实时决策。通过将边缘计算与人工智能驱动的视觉相结合，各行业可以实现更高的可扩展性、更快的响应速度和更强的安全性，使实时人工智能视觉成为2025年自动化的基石。(Ultralytics)\n\n**5. 道德和负责任的人工智能:**\n*   随着人工智能越来越多地参与决策过程，围绕偏见、隐私和责任的伦理问题变得越来越重要。人工智能模型需要确保公平、透明和符合法规，尤其是在医疗保健、金融和招聘等敏感行业。 (Ultralytics)\n*   2025年，预计会有更严格的法规，并更加强调负责任的人工智能，推动企业开发可解释和可审计的模型。积极采用道德人工智能框架的企业将赢得消费者的信任，满足合规要求，并确保人工智能应用的长期可持续性. (Ultralytics)\n\n**6. 多模态人工智能:**\n\n*   2025年多模态AI将成为企业采用AI的主要驱动力，助力改善客户体验，提高运营效率，开发新的商业模式。例如，多模态AI将广泛用于医疗领域，通过分析医疗记录、成像数据、基因组信息等推进个性化医疗；在零售、金融服务、制造业等领域的应用也将不断扩展。(新华网)\n\n**7. AI推理能力增强:**\n\n*   AI的逻辑推理能力在提升。OpenAI在2024年9月发布推理模型o1，并在12月迅速升级到o3版本，新模型在数学、编程、博士级科学问答等复杂问题上，表现出超越部分人类专家的水平。谷歌也在12月发布其最新推理模型“双子座2.0闪电思维”，专注于解决编程、数学及物理等领域的难题。(新华网)\n\n**8. 智能体普及和具身智能:**\n\n*   智能体的出现频率将越来越高。智能体指使用AI技术，能够自主感知环境、作出决策并执行行动的智能实体。业界普遍认为，这种智能体2025年将变得更加普及，且能处理更复杂的任务，将人类从一些重复且琐碎的工作中解放出来。(新华网)\n*   智能体还可结合物理实体，形成“具身智能”，如自动驾驶汽车、具身智能机器人等。美国特斯拉公司研发的人形机器人“擎天柱”已可在工厂行走、分拣电池，还能以接近人类的灵活度用单手稳稳接住迎面抛来的网球，有望在2025年实现小批量生产并投入使用。(新华网)\n\n**9. AI驱动的智能代理将改变工作形态:**\n\n*   预计到2025年，新一代AI 驱动的代理将能够处理更多任务，甚至可以代表用户来执行某些任务。(Microsoft Research)\n\n**10. 量子人工智能崭露头角:**\n\n*   量子人工智能仍处于起步阶段，但它已经在科技和研究界掀起了波澜。它结合了量子计算和人工智能，旨在解决传统人工智能无法高效处理的复杂问题。IBM 和谷歌等公司正在大力投资量子人工智能，显示出其改变医疗、金融和物流等行业的潜力。(Botpress)\n\n**11. AI安全治理体系持续完善:**\n\n*   模型能力提升与风险预防并重，AI安全治理体系持续完善。基础模型在自主决策上的持续进步带来了潜在的失控风险，如何引入新的技术监管方法，如何在人工监管上平衡行业发展和风险管控？(华尔街见闻)\n\n**12. AI对能源的需求大幅增长:**\n\n*   推理端算力需求大幅增长，基于云的人工智能系统需要消耗更多的能源，可持续发展日益紧迫。(中信建投)\n\n**13. 人工智能将发展为巨大的市场:**\n\n*   联合国的一份报告预测，到2033年，人工智能将发展成为价值4.8万亿美元的全球市场，规模相当于德国当前的经济总量。(UN News)\n\n**14. AI智能体规模应用的"拐点时刻":**\n\n*   2025年，AI领域的热议话题已经从大语言模型（LLMs）转向了AI智能体（AI Agent）。根据Gartner最新预测，企业软件中整合自主型AI的比例将从2024年的不足1%跃升至2028年的33%；同时，超过15%的日常工作决策将交由AI智能体自主完成。(IBM)\n')] role='model'
#   - 安全评级: None
#   - 有grounding_metadata: True
#
# ==================================================

# %%
# 详细查看grounding metadata（Google搜索结果的核心数据）
if response and response.candidates:
    candidate = response.candidates[0]
    
    if hasattr(candidate, 'grounding_metadata') and candidate.grounding_metadata:
        print("=== Grounding Metadata (Google搜索结果) ===")
        grounding_metadata = candidate.grounding_metadata
        
        print(f"Grounding Metadata 类型: {type(grounding_metadata)}")
        # print(f"Grounding Metadata 属性: {dir(grounding_metadata)}")
        print()
        
        # 查看搜索结果块
        if hasattr(grounding_metadata, 'grounding_chunks'):
            print(f"搜索结果块数量: {len(grounding_metadata.grounding_chunks)}")
            print()
            
           
        # 尝试将grounding_metadata转换为字典查看完整结构
        try:
            # 如果有to_dict方法
            if hasattr(grounding_metadata, 'to_dict'):
                metadata_dict = grounding_metadata.to_dict()
                print("=== Grounding Metadata 完整结构 (字典格式) ===")
                pprint(metadata_dict, depth=3)
            else:
                print("=== Grounding Metadata 原始对象 ===")
                # 打印更详细的结构信息
                print("Grounding Chunks:")
                for i, chunk in enumerate(grounding_metadata.grounding_chunks):
                    print(f"\nChunk {i+1}:")
                    if hasattr(chunk, 'web') and chunk.web:
                        print(f"  Title: {chunk.web.title}")
                        print(f"  URI: {chunk.web.uri}")
                
                print("\nGrounding Supports:")
                for i, support in enumerate(grounding_metadata.grounding_supports):
                    print(f"\nSupport {i+1}:")
                    print(f"  Confidence Scores: {support.confidence_scores}")
                    print(f"  Chunk Indices: {support.grounding_chunk_indices}")
                    if hasattr(support, 'segment'):
                        print(f"  Segment Text: {support.segment.text}")
                        print(f"  Start Index: {support.segment.start_index}")
                        print(f"  End Index: {support.segment.end_index}")
        except Exception as e:
            print(f"无法转换为字典: {e}")
    else:
        print("没有找到grounding_metadata")
        
print("\n" + "="*50 + "\n")
# Out:
# === Grounding Metadata (Google搜索结果) ===
# Grounding Metadata 类型: <class 'google.genai.types.GroundingMetadata'>
#
# 搜索结果块数量: 9
#
# === Grounding Metadata 原始对象 ===
# Grounding Chunks:
#
# Chunk 1:
#   Title: botpress.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg==
#
# Chunk 2:
#   Title: ultralytics.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV
#
# Chunk 3:
#   Title: news.cn
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA==
#
# Chunk 4:
#   Title: ibm.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9
#
# Chunk 5:
#   Title: faiusr.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q==
#
# Chunk 6:
#   Title: aibase.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEHU3ycK0PWvhncXu--4kORL53bqxNNVvg0ytyGBexGMQFEzKfv0y1RBXsMTFgcZlM-vcWfV2iB79ctyvMe0cAze1Z9d9qySmWHaAzsbIXMDGdqUWjDU85llZCKEb99nzVdI0t1Jg==
#
# Chunk 7:
#   Title: wallstreetcn.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEEQbSz58WXeHQcoJBtpp-dRZxuOgNXQnzbnHoFS3eNBCONdbOvGvu0tZKF9ibn5JYN2nXHmPjxL4Usq_Dve7CNcTZJz6uDrLfEs8oqR5AS0uM87HGmv0S9ak6sY3dUfacBWqV_
#
# Chunk 8:
#   Title: microsoft.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEafdeMHV1HhtUZf-IfKys45Z2PqZVgx2RHAPsIC3DNqskPRPFes0O8IQLeXsl_o27XDeGUm3YudU_O4UpjY_lMvfUbNNjZkqO0kujcIEwrTUW-4ozzWD51MJY40-BbEMzHPTPffnFki0vd7pdHU9Yju1iiBlIVzpGZ09sxcPtI1Ts=
#
# Chunk 9:
#   Title: poe.com
#   URI: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFsV5udcTtbmVqcjziMBc7ODERfsUJHtbjO5TNB8qBp5ZKlfkJGowJerid2vTdS8iBudJ-7gT52NdiGoKEFUZTjzTBZ15SPYIcrme5mchowFT7w6Cv6x4BR8aNRo3lqweGl39TWjmiJlRdI6zITbPFjlox9NQ==
#
# Grounding Supports:
#
# Support 1:
#   Confidence Scores: [0.66445225, 0.62576914, 0.65121603, 0.65414613]
#   Chunk Indices: [0, 1, 2, 3]
#   Segment Text: **1.
#   Start Index: 87
#   End Index: 91
#
# Support 2:
#   Confidence Scores: [0.62850064, 0.6377137, 0.6919088, 0.6296653, 0.6295386]
#   Chunk Indices: [2, 3, 1, 4, 0]
#   Segment Text: 人工智能的可及性和更低的培训成本:**
#   Start Index: 92
#   End Index: 143
#
# Support 3:
#   Confidence Scores: [0.6263726, 0.60634434, 0.6043788, 0.9907941]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   人工智能的普及正在改变模型的训练和部署方式。模型架构和硬件效率的提高大大降低了大规模人工智能系统的训练成本，使更多用户可以使用这些系统。
#   Start Index: 144
#   End Index: 352
#
# Support 4:
#   Confidence Scores: [0.64865553, 0.63128465, 0.6305846, 0.76248854, 0.601958]
#   Chunk Indices: [3, 2, 4, 1, 0]
#   Segment Text: (Ultralytics)
#   Start Index: 353
#   End Index: 366
#
# Support 5:
#   Confidence Scores: [0.65931714, 0.64470875, 0.66129243, 0.6515365]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   人工智能技术的普及促进了各行各业的创新，使初创企业和小型企业能够开发和部署曾经属于大型企业领域的人工智能解决方案。培训成本的降低也加快了迭代周期，使人工智能模型的实验和完善更加迅速。(Ultralytics)
#   Start Index: 367
#   End Index: 657
#
# Support 6:
#   Confidence Scores: [0.61172867, 0.61772573, 0.6204979, 0.6512975, 0.6637711]
#   Chunk Indices: [4, 0, 1, 2, 3]
#   Segment Text: **2.
#   Start Index: 659
#   End Index: 663
#
# Support 7:
#   Confidence Scores: [0.64935726, 0.63354176, 0.6448718]
#   Chunk Indices: [2, 3, 1]
#   Segment Text: *   人工智能代理正变得越来越先进，为实现人工通用智能（AGI）架起了桥梁。与传统的人工智能系统专为狭窄的任务而设计不同，这些代理可以不断学习，适应动态环境，并根据实时数据做出独立决策。(Ultralytics)
#   Start Index: 716
#   End Index: 997
#
# Support 8:
#   Confidence Scores: [0.6348093, 0.6948899]
#   Chunk Indices: [2, 1]
#   Segment Text: *   2025年，多代理系统，即多个人工智能代理合作实现复杂目标，有望变得更加突出。这些系统可以优化工作流程，产生洞察力，并协助各行各业做出决策。(Ultralytics)
#   Start Index: 998
#   End Index: 1217
#
# Support 9:
#   Confidence Scores: [0.6315523, 0.6558041, 0.65727216]
#   Chunk Indices: [1, 2, 3]
#   Segment Text: **3.
#   Start Index: 1219
#   End Index: 1223
#
# Support 10:
#   Confidence Scores: [0.64540625, 0.6621905, 0.7682976, 0.6757244]
#   Chunk Indices: [2, 4, 1, 3]
#   Segment Text: *   视觉转换器（ViTs）、边缘人工智能和3D视觉等新方法正在推进实时感知和分析。这些技术为自动化、医疗保健、可持续发展和机器人技术带来了新的可能性，使计算机视觉比以往任何时候都更加高效和强大。(Ultralytics)
#   Start Index: 1252
#   End Index: 1542
#
# Support 11:
#   Confidence Scores: [0.64526653, 0.63975203, 0.6572009, 0.77252924, 0.68257725]
#   Chunk Indices: [2, 4, 3, 1, 0]
#   Segment Text: *   自监督学习、视觉转换器和边缘人工智能等先进技术有望提升机器感知、分析和与世界交互的能力。这些创新将继续推动实时图像处理、物体检测和环境监测的发展，使人工智能驱动的视觉系统更高效、更易于在各行各业使用。(Ultralytics)
#   Start Index: 1543
#   End Index: 1860
#
# Support 12:
#   Confidence Scores: [0.74308705, 0.6232635, 0.65712684, 0.6340591, 0.6616463]
#   Chunk Indices: [5, 1, 2, 6, 3]
#   Segment Text: **4.
#   Start Index: 1862
#   End Index: 1866
#
# Support 13:
#   Confidence Scores: [0.6587513, 0.6259446, 0.62065035, 0.63107675]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   边缘计算的一个关键优势是它能够在云连接有限或不切实际的环境中实现实时决策。通过将边缘计算与人工智能驱动的视觉相结合，各行业可以实现更高的可扩展性、更快的响应速度和更强的安全性，使实时人工智能视觉成为2025年自动化的基石。(Ultralytics)
#   Start Index: 1889
#   End Index: 2231
#
# Support 14:
#   Confidence Scores: [0.6235908, 0.6449508, 0.73884845, 0.6670597]
#   Chunk Indices: [1, 2, 6, 3]
#   Segment Text: **5.
#   Start Index: 2233
#   End Index: 2237
#
# Support 15:
#   Confidence Scores: [0.66804373, 0.6115556, 0.66296685, 0.66758406]
#   Chunk Indices: [4, 2, 1, 3]
#   Segment Text: *   随着人工智能越来越多地参与决策过程，围绕偏见、隐私和责任的伦理问题变得越来越重要。人工智能模型需要确保公平、透明和符合法规，尤其是在医疗保健、金融和招聘等敏感行业。
#   Start Index: 2275
#   End Index: 2525
#
# Support 16:
#   Confidence Scores: [0.64865553, 0.63128465, 0.6305846, 0.76248854, 0.601958]
#   Chunk Indices: [3, 2, 4, 1, 0]
#   Segment Text: (Ultralytics)
#   Start Index: 2526
#   End Index: 2539
#
# Support 17:
#   Confidence Scores: [0.61341566, 0.60368085, 0.6465982]
#   Chunk Indices: [4, 3, 1]
#   Segment Text: *   2025年，预计会有更严格的法规，并更加强调负责任的人工智能，推动企业开发可解释和可审计的模型。积极采用道德人工智能框架的企业将赢得消费者的信任，满足合规要求，并确保人工智能应用的长期可持续性.
#   Start Index: 2540
#   End Index: 2825
#
# Support 18:
#   Confidence Scores: [0.6550064, 0.6427462, 0.6329285, 0.7451998, 0.6284493]
#   Chunk Indices: [3, 2, 4, 1, 0]
#   Segment Text: (Ultralytics)
#   Start Index: 2826
#   End Index: 2839
#
# Support 19:
#   Confidence Scores: [0.65246826, 0.6240761, 0.6577057, 0.66604525]
#   Chunk Indices: [7, 1, 2, 3]
#   Segment Text: **6.
#   Start Index: 2841
#   End Index: 2845
#
# Support 20:
#   Confidence Scores: [0.62413216, 0.62509483, 0.64235544, 0.66229934]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   2025年多模态AI将成为企业采用AI的主要驱动力，助力改善客户体验，提高运营效率，开发新的商业模式。例如，多模态AI将广泛用于医疗领域，通过分析医疗记录、成像数据、基因组信息等推进个性化医疗；在零售、金融服务、制造业等领域的应用也将不断扩展。(新华网)
#   Start Index: 2872
#   End Index: 3233
#
# Support 21:
#   Confidence Scores: [0.64067334, 0.64974105, 0.7781705, 0.66865027]
#   Chunk Indices: [1, 2, 6, 3]
#   Segment Text: **7.
#   Start Index: 3235
#   End Index: 3239
#
# Support 22:
#   Confidence Scores: [0.64408934, 0.6180358, 0.65950346]
#   Chunk Indices: [2, 3, 1]
#   Segment Text: *   AI的逻辑推理能力在提升。OpenAI在2024年9月发布推理模型o1，并在12月迅速升级到o3版本，新模型在数学、编程、博士级科学问答等复杂问题上，表现出超越部分人类专家的水平。谷歌也在12月发布其最新推理模型“双子座2.0闪电思维”，专注于解决编程、数学及物理等领域的难题。(新华网)
#   Start Index: 3265
#   End Index: 3649
#
# Support 23:
#   Confidence Scores: [0.6238746, 0.63487, 0.6660226]
#   Chunk Indices: [1, 2, 3]
#   Segment Text: **8.
#   Start Index: 3651
#   End Index: 3655
#
# Support 24:
#   Confidence Scores: [0.61488456, 0.6386654, 0.6004197, 0.6331675]
#   Chunk Indices: [2, 3, 4, 1]
#   Segment Text: *   智能体的出现频率将越来越高。智能体指使用AI技术，能够自主感知环境、作出决策并执行行动的智能实体。业界普遍认为，这种智能体2025年将变得更加普及，且能处理更复杂的任务，将人类从一些重复且琐碎的工作中解放出来。(新华网)
#   Start Index: 3691
#   End Index: 4009
#
# Support 25:
#   Confidence Scores: [0.63091147, 0.60211444, 0.6564039, 0.6487604]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   智能体还可结合物理实体，形成“具身智能”，如自动驾驶汽车、具身智能机器人等。美国特斯拉公司研发的人形机器人“擎天柱”已可在工厂行走、分拣电池，还能以接近人类的灵活度用单手稳稳接住迎面抛来的网球，有望在2025年实现小批量生产并投入使用。(新华网)
#   Start Index: 4010
#   End Index: 4371
#
# Support 26:
#   Confidence Scores: [0.64930135, 0.6233315, 0.6662363]
#   Chunk Indices: [2, 1, 3]
#   Segment Text: **9.
#   Start Index: 4373
#   End Index: 4377
#
# Support 27:
#   Confidence Scores: [0.6547058, 0.6488081]
#   Chunk Indices: [3, 1]
#   Segment Text: *   预计到2025年，新一代AI 驱动的代理将能够处理更多任务，甚至可以代表用户来执行某些任务。(Microsoft Research)
#   Start Index: 4427
#   End Index: 4575
#
# Support 28:
#   Confidence Scores: [0.66874474, 0.6287218, 0.65947646, 0.6378892, 0.66712236, 0.71903133]
#   Chunk Indices: [4, 0, 2, 1, 3, 6]
#   Segment Text: **10.
#   Start Index: 4577
#   End Index: 4582
#
# Support 29:
#   Confidence Scores: [0.61877126, 0.640033, 0.6578696, 0.65452856]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   量子人工智能仍处于起步阶段，但它已经在科技和研究界掀起了波澜。它结合了量子计算和人工智能，旨在解决传统人工智能无法高效处理的复杂问题。IBM 和谷歌等公司正在大力投资量子人工智能，显示出其改变医疗、金融和物流等行业的潜力。(Botpress)
#   Start Index: 4618
#   End Index: 4957
#
# Support 30:
#   Confidence Scores: [0.65760326, 0.6263268, 0.6092717, 0.66345286]
#   Chunk Indices: [0, 1, 2, 3]
#   Segment Text: **11.
#   Start Index: 4959
#   End Index: 4964
#
# Support 31:
#   Confidence Scores: [0.65476745, 0.6563116, 0.630879, 0.6644379]
#   Chunk Indices: [7, 2, 1, 3]
#   Segment Text: **12.
#   Start Index: 5279
#   End Index: 5284
#
# Support 32:
#   Confidence Scores: [0.61480534, 0.6469455, 0.64698964]
#   Chunk Indices: [2, 3, 1]
#   Segment Text: *   推理端算力需求大幅增长，基于云的人工智能系统需要消耗更多的能源，可持续发展日益紧迫。(中信建投)
#   Start Index: 5322
#   End Index: 5466
#
# Support 33:
#   Confidence Scores: [0.68354815, 0.6258512, 0.6010344, 0.66010493]
#   Chunk Indices: [8, 1, 2, 3]
#   Segment Text: **13.
#   Start Index: 5468
#   End Index: 5473
#
# Support 34:
#   Confidence Scores: [0.62789994, 0.6297013, 0.6209587, 0.6692275]
#   Chunk Indices: [2, 4, 3, 1]
#   Segment Text: *   联合国的一份报告预测，到2033年，人工智能将发展成为价值4.8万亿美元的全球市场，规模相当于德国当前的经济总量。(UN News)
#   Start Index: 5518
#   End Index: 5688
#
# Support 35:
#   Confidence Scores: [0.62486756, 0.6520753, 0.66275245]
#   Chunk Indices: [1, 2, 3]
#   Segment Text: **14.
#   Start Index: 5690
#   End Index: 5695
#
# Support 36:
#   Confidence Scores: [0.6738192]
#   Chunk Indices: [1]
#   Segment Text: *   2025年，AI领域的热议话题已经从大语言模型（LLMs）转向了AI智能体（AI Agent）。根据Gartner最新预测，企业软件中整合自主型AI的比例将从2024年的不足1%跃升至2028年的33%；同时，超过15%的日常工作决策将交由AI智能体自主完成。(IBM)
#   Start Index: 5741
#   End Index: 6046
#
# ==================================================

# %%
mock_state = {"id": 0}

# resolve the urls to short urls for saving tokens and time
resolved_urls = resolve_urls(
    response.candidates[0].grounding_metadata.grounding_chunks,  mock_state["id"]

)

print("resolved_urls:\n", resolved_urls, "\n")    
# Gets the citations and adds them to the generated text
citations = get_citations(response, resolved_urls)
print("citations:\n", citations, "\n"   )
modified_text = insert_citation_markers(response.text, citations)
print("modified_text:\n", modified_text, "\n")
sources_gathered = [item for citation in citations for item in citation["segments"]]
print("sources_gathered:\n", sources_gathered, "\n" )

# return {
#     "sources_gathered": sources_gathered,
#     "search_query": [state["search_query"]],
#     "web_research_result": [modified_text],
# }
# Out:
# resolved_urls:
#  {'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg==': 'https://vertexaisearch.cloud.google.com/id/0-0', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV': 'https://vertexaisearch.cloud.google.com/id/0-1', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA==': 'https://vertexaisearch.cloud.google.com/id/0-2', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9': 'https://vertexaisearch.cloud.google.com/id/0-3', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q==': 'https://vertexaisearch.cloud.google.com/id/0-4', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEHU3ycK0PWvhncXu--4kORL53bqxNNVvg0ytyGBexGMQFEzKfv0y1RBXsMTFgcZlM-vcWfV2iB79ctyvMe0cAze1Z9d9qySmWHaAzsbIXMDGdqUWjDU85llZCKEb99nzVdI0t1Jg==': 'https://vertexaisearch.cloud.google.com/id/0-5', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEEQbSz58WXeHQcoJBtpp-dRZxuOgNXQnzbnHoFS3eNBCONdbOvGvu0tZKF9ibn5JYN2nXHmPjxL4Usq_Dve7CNcTZJz6uDrLfEs8oqR5AS0uM87HGmv0S9ak6sY3dUfacBWqV_': 'https://vertexaisearch.cloud.google.com/id/0-6', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEafdeMHV1HhtUZf-IfKys45Z2PqZVgx2RHAPsIC3DNqskPRPFes0O8IQLeXsl_o27XDeGUm3YudU_O4UpjY_lMvfUbNNjZkqO0kujcIEwrTUW-4ozzWD51MJY40-BbEMzHPTPffnFki0vd7pdHU9Yju1iiBlIVzpGZ09sxcPtI1Ts=': 'https://vertexaisearch.cloud.google.com/id/0-7', 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFsV5udcTtbmVqcjziMBc7ODERfsUJHtbjO5TNB8qBp5ZKlfkJGowJerid2vTdS8iBudJ-7gT52NdiGoKEFUZTjzTBZ15SPYIcrme5mchowFT7w6Cv6x4BR8aNRo3lqweGl39TWjmiJlRdI6zITbPFjlox9NQ==': 'https://vertexaisearch.cloud.google.com/id/0-8'}
#
# citations:
#  [{'start_index': 87, 'end_index': 91, 'segments': [{'label': 'botpress', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-0', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg=='}, {'label': 'ultralytics', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-1', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV'}, {'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9'}]}, {'start_index': 92, 'end_index': 143, 'segments': [{'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9'}, {'label': 'ultralytics', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-1', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV'}, {'label': 'faiusr', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-4', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q=='}, {'label': 'botpress', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-0', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg=='}]}, {'start_index': 144, 'end_index': 352, 'segments': [{'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'faiusr', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-4', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https ...
#
# modified_text:
#  基于最新的研究和分析，以下是2025年人工智能发展的主要趋势：
#
# **1. 人工智能的可及性和更低的培训成本:**
# *   人工智能的普及正在改变模型的训练和部署方式。模型架构和硬件 [botpress](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)效率的提高大大降低了大规模人工智能系统的训练成本，使更多用户可以使用这些系统。 (Ultralytics [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [botpress](https://vertexaisearch.cloud.google.com/id/0-0))
# *   人工智能技术的普及促进了各行各业的创新，使初创企业和小型企业能够开发和部署曾经属于大型企业领域的人工智能解决方案。培训成本的降低也加快了迭代周期，使人工智能模型的实验和完善更加迅速。(Ultralytics)
#
# **2. 人工智能代理和人工通用智能（AGI）:**
# *   人工智能代理正变得越来越先进，为实现人工通用智能（AGI）架起了桥梁。与传统的人工智能系统专为狭窄的任务而设计不同，这些代理可以不断 [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)学习，适应动态环境，并根据实 [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [botpress](https://vertexaisearch.cloud.google.com/id/0-0)时数据做出独立决策。(Ultralytics)
# *   2025年，多代理系统，即多个人工智能代理合作实现复杂目标，有望变得更加突出。这些系统可以优化工作流程，产生洞察力，并协助各行各业做出决策。(Ultralytics)
#
# **3. 计算机视觉的进步:**
# *   视觉转换器（ViTs）、边缘人工智能和3D视觉等新方法正在推进实时感知和分析。这些技术为自动化、医疗保健、可持续发展和机器人技术带来了新的可能性，使计算机视觉比以往任何时候都更加高效和强大。(Ultralytics)
# *   自监督学习、视觉转换器和边缘人工智能等先进技术有望提升机器感知、分析和与世界交互的能力。 [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)这些创新将继 [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [botpress](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)续推动实时图像处理、物体检测和环境监测的发展，使人工智能驱动的视觉系统更高效、更易于在各行各业使用。(Ultralytics)
#
# **4. 边缘人工智能:**
# *   边缘计算的一个关键优势是它能够在云连接有限或不切实际的环境中实现实时决策。通过将边缘计算与人工智能驱动的视觉相结合，各行业可以实现更高的可扩展性、更快的响应速度和更强的安全性，使实时人工智能视觉成为2025年自动化的基石。(Ultralytics)
#
# **5. 道德和负责任的人工智能:**
# *   随着人工智能越来越多地参与决策过程，围绕偏见、隐私和责任的伦理问题变得越来越重要。人工智能模型需要确保公平、透明和符合法规，尤其是在医疗保健、金融和招聘等敏感行业。 (Ultralytics)
# *   [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) 2025年，预计会有更严格的法规，并更加强调负责任的人工智能，推动企业开发可解释和可审计的模型。积极采用道德人工智能框架的企业将赢得消费者的信任，满足合规要求，并确保人工智能应用的长期可持续性. (Ultralytics)
#
# **6. 多模态人工智能:**
#
# *   2025年多模态AI将成为企业采用AI的主要驱动力，助力改善客户体验，提高运营效率，开发新的商业模式。例如，多模态AI将广泛用于医疗领域，通过分析医疗记录、成像数据、基因 [news](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)组信息等推进 [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)个性化医疗；在零售、金融服务、制造业等领域的应用也将不断扩展。(新华网)
#
# **7. AI推理能力增强:**
#
# *   AI的逻辑推理能力在提升。OpenAI在2024年9月发布推理模型o1，并在12月迅速升级到o3版本，新模型在数学、编程、博士级科学问答等复杂问题上，表现出超越部分人类专家的水平。谷歌也在12月发布其最新推理模型“双子座2.0闪电思维”，专注于解决编程、数学及物理等领域的难题。(新华网)
#
# **8. 智能体普及和具身智能:**
#
# *   智能体的出现频率将越来越高。智能体指使用AI技术，能够自主感知环境、作出决策并执行行动的智能实体。业界普遍认为，这种智能体2025年将变得更加普及，且能处理更复杂的任务，将人类从 [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)一些重复且琐碎的工作中解放出来。(新华网)
# *   智能体还可结合物理实体，形成“具身智能”，如自动驾驶汽车、具身智能机器人等。美国特斯拉公司研发的人形机器人“擎天柱”已可在工厂行走、分拣电池，还能以接近人类的灵活度用单手稳稳接住迎面抛来的网球，有望在2025年实现小批量生产并投入使用。(新华网)
#
# **9. AI驱动的智能代理将改变工作形态:**
#
# *   预计到2025年，新一代AI 驱动的代理将能够处理更多任务，甚至可以代表用户来执行某些任务。(Microsoft Research)
#
# **10. 量子人工智能崭露头角:**
#
# *   量子人工智能仍处于起步阶段，但它已经在科技和研究界掀起了波澜。它结合了量子计算和人工智能 [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [botpress](https://vertexaisearch.cloud.google.com/id/0-0)，旨在解决传 [aibase](https://vertexaisearch.cloud.google.com/id/0-5) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-6) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)统人工智能无法高效处理的复杂问题。IBM 和谷歌等公司正在大力投资量子人工智能，显示出其改变医疗、金融和物流等行业的潜力。(Botpress)
#
# **11. AI安全治理体系持续完善:**
#
# *   模型能力提升与风险预防并重，AI安全治理体系持续完善。基础模型在自主决策上的持续进步带来了潜在的失控风险，如何引入新的技术监管方法，如何在人工监管上平衡行业发展和风险管控？(华尔街见闻)
#
# **12. AI对能源的需求大幅增长:**
#
# *   推理端算力需求大幅增长，基于云的人工智能系统需要消耗更多的能源，可持续发展日益紧迫。(中信建投)
#
# **13. 人工智能将发展为巨大的市场:**
#
# *   联合国的一份报告预测，到2033年，人工智能将发展成为价值4.8万亿美元的全球市场，规模相当于德国当前的经济总量。(UN News [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1))
#
# **1 [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-6) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)4. AI智能体规模应用的"拐点时刻":**
#
# *   2025年，AI领域的热议话题已经从大语言模型（LLMs）转向了AI智能体（AI Agent）。根据Gartner最新预测，企业软件中整合自主型AI的比例将从2024年的不足1%跃升至2028年的33%；同时，超过15%的日常工作决策将交由AI智能体自主完成。(IBM)
#  [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https: [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [botpress](https://vertexaisearch.cloud.google.com/id/0-0)//vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://ve [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)rtexaisearch.c [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [botpress](https://vertexaisearch.cloud.google.com/id/0-0)loud.g [microsoft](https://vertexaisearch.cloud.google.com/id/0-7) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)oogle.com/id/0-1) [poe](https://vertexaisearch.cloud.google.com/id/0-8) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1).cloud [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-6) [ibm](https://vertexaisearch.cloud.google.com/id/0-3).google.com/id/0-1) [microsoft](https://vertexaisearch.cloud.google.com/id/0-7) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.go [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)ogle.c [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3)om/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [news](https://vertexaisearch.cloud.google.com/id/0-2) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [bot [news](https://vertexaisearch.cloud.google.com/id/0-2) [ibm](https://vertexaisearch.cloud.google.com/id/0-3) [faiusr](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-1)press](https://vertexaisearch.cloud.google.com/id/0-0) [news](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.g ...
#
# sources_gathered:
#  [{'label': 'botpress', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-0', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg=='}, {'label': 'ultralytics', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-1', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV'}, {'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9'}, {'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY_qgHZ_PkA0MImuZuX9oTmK3OMsBIoEeEen1TEo0F7BjpiVPFDyRW4JAu9'}, {'label': 'ultralytics', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-1', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFjFtNsDD79h2up8Z2rJRiKnC-faj6P3ojQZVMxR95oaRQ_Gc93kYvx2IO9MXLJUhJqSqEI_vHwjWg22iCgTd-oM6Jd3Wg51IK1zERbAXQSf6UsqBjk7iFzYqwna2xQKRi_4nyyfwW7ITQilSYwdXUYzuMxCFn7e6mj_RLouK7lkmWe3EsOY-NoivA5FF2jRU6Qupe66UuV'}, {'label': 'faiusr', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-4', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q=='}, {'label': 'botpress', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-0', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFuLVbyL09GuHpcgAOR-cpy5Suozvy7rbNuYEdyf-Jq-f2rAEAFOhNA1Z9Z55lACNlHvzMGppGo-De7DLvmTBW4dKJc56eQVLbAMBk06VviknYb8kXnbCQu1E7VM9AguIqzayQOyLV7UGrF6JSm-J6liGGOug_Eudonpg=='}, {'label': 'news', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-2', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHIG1SQBGVTlUDzGv7BATCbLy0rBgg_EptKWq4jGZ1MN0cCEfMI12do6wRwTSKU8tgVOtoU0Bb11RftWtNM1PcG5j3ABh2MEwPeJTDG9VKFBhCbP9UYM-r1Msogq5SHAhwdXV0DIFHldBccRHezY_gLwFojww173UkpyVOj3F7SXFOxkA=='}, {'label': 'faiusr', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-4', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG4-ih1Kt7Ba9i_HtyB3TalUyPn0XlP20-pDl5MihTlxi-zfH_V3wvXfQFXt2hQyUqUeKTF6sFTqXJ6P-I6Bv058H7sKHAtwH7hTXqDu5oCkto_BVc1pCkkvQjD8Xc9uo0Ukswm8gbosjAM-VA9i9FgqwvZ-PyxbfnlybqdEK6P4Q=='}, {'label': 'ibm', 'short_url': 'https://vertexaisearch.cloud.google.com/id/0-3', 'value': 'https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGNTuILKHWvdzfzlAmKhDbcKDkg6BKuUUiRN_78uiypNfh1IQyzJa3GpLn3WSOdRfnOQUZTM3RS2JfOriJNMtMrPjxjJPY ...

# %%
# 测试web_research函数的完整流程
if response and response.candidates and hasattr(response.candidates[0], 'grounding_metadata'):
    print("=== 测试完整的web_research处理流程 ===")
    
    # 模拟state参数
    mock_state = {"id": 0}
    
    # 1. 解析URLs
    try:
        resolved_urls = resolve_urls(
            response.candidates[0].grounding_metadata.grounding_chunks, 
            mock_state["id"]
        )
        print(f"解析后的URL数量: {len(resolved_urls)}")
        print("解析后的URLs:")
        for url in resolved_urls:
            print(f"  - 短URL: {url['short_url']}")
            print(f"    原URL: {url['value']}")
            print()
    except Exception as e:
        print(f"URL解析失败: {e}")
        resolved_urls = []
    
    # 2. 获取引用
    try:
        citations = get_citations(response, resolved_urls)
        print(f"引用数量: {len(citations)}")
        print("引用信息:")
        for i, citation in enumerate(citations):
            print(f"  引用 {i+1}:")
            print(f"    - 段落数量: {len(citation['segments'])}")
            for segment in citation['segments']:
                print(f"      * 短URL: {segment['short_url']}")
                print(f"        标题: {segment.get('title', 'N/A')}")
    except Exception as e:
        print(f"引用获取失败: {e}")
        citations = []
    
    # 3. 插入引用标记
    try:
        modified_text = insert_citation_markers(response.text, citations)
        print("\n=== 插入引用标记后的文本 ===")
        print(modified_text)
        
        # 收集所有来源
        sources_gathered = [item for citation in citations for item in citation["segments"]]
        print(f"\n收集到的来源数量: {len(sources_gathered)}")
        
    except Exception as e:
        print(f"引用标记插入失败: {e}")
        
print("\n" + "="*50 + "\n")
# Out:
# === 测试完整的web_research处理流程 ===
# 解析后的URL数量: 9
# 解析后的URLs:
# URL解析失败: string indices must be integers, not 'str'
# 引用数量: 36
# 引用信息:
#   引用 1:
#     - 段落数量: 0
#   引用 2:
#     - 段落数量: 0
#   引用 3:
#     - 段落数量: 0
#   引用 4:
#     - 段落数量: 0
#   引用 5:
#     - 段落数量: 0
#   引用 6:
#     - 段落数量: 0
#   引用 7:
#     - 段落数量: 0
#   引用 8:
#     - 段落数量: 0
#   引用 9:
#     - 段落数量: 0
#   引用 10:
#     - 段落数量: 0
#   引用 11:
#     - 段落数量: 0
#   引用 12:
#     - 段落数量: 0
#   引用 13:
#     - 段落数量: 0
#   引用 14:
#     - 段落数量: 0
#   引用 15:
#     - 段落数量: 0
#   引用 16:
#     - 段落数量: 0
#   引用 17:
#     - 段落数量: 0
#   引用 18:
#     - 段落数量: 0
#   引用 19:
#     - 段落数量: 0
#   引用 20:
#     - 段落数量: 0
#   引用 21:
#     - 段落数量: 0
#   引用 22:
#     - 段落数量: 0
#   引用 23:
#     - 段落数量: 0
#   引用 24:
#     - 段落数量: 0
#   引用 25:
#     - 段落数量: 0
#   引用 26:
#     - 段落数量: 0
#   引用 27:
#     - 段落数量: 0
#   引用 28:
#     - 段落数量: 0
#   引用 29:
#     - 段落数量: 0
#   引用 30:
#     - 段落数量: 0
#   引用 31:
#     - 段落数量: 0
#   引用 32:
#     - 段落数量: 0
#   引用 33:
#     - 段落数量: 0
#   引用 34:
#     - 段落数量: 0
#   引用 35:
#     - 段落数量: 0
#   引用 36:
#     - 段落数量: 0
#
# === 插入引用标记后的文本 ===
# 基于最新的研究和分析，以下是2025年人工智能发展的主要趋势：
#
# **1. 人工智能的可及性和更低的培训成本:**
# *   人工智能的普及正在改变模型的训练和部署方式。模型架构和硬件效率的提高大大降低了大规模人工智能系统的训练成本，使更多用户可以使用这些系统。 (Ultralytics)
# *   人工智能技术的普及促进了各行各业的创新，使初创企业和小型企业能够开发和部署曾经属于大型企业领域的人工智能解决方案。培训成本的降低也加快了迭代周期，使人工智能模型的实验和完善更加迅速。(Ultralytics)
#
# **2. 人工智能代理和人工通用智能（AGI）:**
# *   人工智能代理正变得越来越先进，为实现人工通用智能（AGI）架起了桥梁。与传统的人工智能系统专为狭窄的任务而设计不同，这些代理可以不断学习，适应动态环境，并根据实时数据做出独立决策。(Ultralytics)
# *   2025年，多代理系统，即多个人工智能代理合作实现复杂目标，有望变得更加突出。这些系统可以优化工作流程，产生洞察力，并协助各行各业做出决策。(Ultralytics)
#
# **3. 计算机视觉的进步:**
# *   视觉转换器（ViTs）、边缘人工智能和3D视觉等新方法正在推进实时感知和分析。这些技术为自动化、医疗保健、可持续发展和机器人技术带来了新的可能性，使计算机视觉比以往任何时候都更加高效和强大。(Ultralytics)
# *   自监督学习、视觉转换器和边缘人工智能等先进技术有望提升机器感知、分析和与世界交互的能力。这些创新将继续推动实时图像处理、物体检测和环境监测的发展，使人工智能驱动的视觉系统更高效、更易于在各行各业使用。(Ultralytics)
#
# **4. 边缘人工智能:**
# *   边缘计算的一个关键优势是它能够在云连接有限或不切实际的环境中实现实时决策。通过将边缘计算与人工智能驱动的视觉相结合，各行业可以实现更高的可扩展性、更快的响应速度和更强的安全性，使实时人工智能视觉成为2025年自动化的基石。(Ultralytics)
#
# **5. 道德和负责任的人工智能:**
# *   随着人工智能越来越多地参与决策过程，围绕偏见、隐私和责任的伦理问题变得越来越重要。人工智能模型需要确保公平、透明和符合法规，尤其是在医疗保健、金融和招聘等敏感行业。 (Ultralytics)
# *   2025年，预计会有更严格的法规，并更加强调负责任的人工智能，推动企业开发可解释和可审计的模型。积极采用道德人工智能框架的企业将赢得消费者的信任，满足合规要求，并确保人工智能应用的长期可持续性. (Ultralytics)
#
# **6. 多模态人工智能:**
#
# *   2025年多模态AI将成为企业采用AI的主要驱动力，助力改善客户体验，提高运营效率，开发新的商业模式。例如，多模态AI将广泛用于医疗领域，通过分析医疗记录、成像数据、基因组信息等推进个性化医疗；在零售、金融服务、制造业等领域的应用也将不断扩展。(新华网)
#
# **7. AI推理能力增强:**
#
# *   AI的逻辑推理能力在提升。OpenAI在2024年9月发布推理模型o1，并在12月迅速升级到o3版本，新模型在数学、编程、博士级科学问答等复杂问题上，表现出超越部分人类专家的水平。谷歌也在12月发布其最新推理模型“双子座2.0闪电思维”，专注于解决编程、数学及物理等领域的难题。(新华网)
#
# **8. 智能体普及和具身智能:**
#
# *   智能体的出现频率将越来越高。智能体指使用AI技术，能够自主感知环境、作出决策并执行行动的智能实体。业界普遍认为，这种智能体2025年将变得更加普及，且能处理更复杂的任务，将人类从一些重复且琐碎的工作中解放出来。(新华网)
# *   智能体还可结合物理实体，形成“具身智能”，如自动驾驶汽车、具身智能机器人等。美国特斯拉公司研发的人形机器人“擎天柱”已可在工厂行走、分拣电池，还能以接近人类的灵活度用单手稳稳接住迎面抛来的网球，有望在2025年实现小批量生产并投入使用。(新华网)
#
# **9. AI驱动的智能代理将改变工作形态:**
#
# *   预计到2025年，新一代AI 驱动的代理将能够处理更多任务，甚至可以代表用户来执行某些任务。(Microsoft Research)
#
# **10. 量子人工智能崭露头角:**
#
# *   量子人工智能仍处于起步阶段，但它已经在科技和研究界掀起了波澜。它结合了量子计算和人工智能，旨在解决传统人工智能无法高效处理的复杂问题。IBM 和谷歌等公司正在大力投资量子人工智能，显示出其改变医疗、金融和物流等行业的潜力。(Botpress)
#
# **11. AI安全治理体系持续完善:**
#
# *   模型能力提升与风险预防并重，AI安全治理体系持续完善。基础模型在自主决策上的持续进步带来了潜在的失控风险，如何引入新的技术监管方法，如何在人工监管上平衡行业发展和风险管控？(华尔街见闻)
#
# **12. AI对能源的需求大幅增长:**
#
# *   推理端算力需求大幅增长，基于云的人工智能系统需要消耗更多的能源，可持续发展日益紧迫。(中信建投)
#
# **13. 人工智能将发展为巨大的市场:**
#
# *   联合国的一份报告预测，到2033年，人工智能将发展成为价值4.8万亿美元的全球市场，规模相当于德国当前的经济总量。(UN News)
#
# **14. AI智能体规模应用的"拐点时刻":**
#
# *   2025年，AI领域的热议话题已经从大语言模型（LLMs）转向了AI智能体（AI Agent）。根据Gartner最新预测，企业软件中整合自主型AI的比例将从2024年的不足1%跃升至2028年的33%；同时，超过15%的日常工作决策将交由AI智能体自主完成。(IBM)
#
#
# 收集到的来源数量: 0
#
# ==================================================

# %%
# 直接调用原始的web_research函数进行对比测试
print("=== 直接调用web_research函数 ===")

# 导入需要的类和配置
from agent.state import WebSearchState
from agent.configuration import Configuration
from langchain_core.runnables import RunnableConfig

# 创建模拟的state和config
mock_web_state = WebSearchState(
    search_query=test_query,
    id=0
)

# 创建配置
mock_config = RunnableConfig(
    configurable={
        "query_generator_model": "gemini-2.0-flash-exp",
        "reasoning_model": "gemini-2.0-flash-exp"
    }
)

# 导入web_research函数
from agent.graph import web_research

try:
    # 调用web_research函数
    result = web_research(mock_web_state, mock_config)
    
    print("=== web_research函数返回结果 ===")
    print(f"搜索查询: {result['search_query']}")
    print(f"来源数量: {len(result['sources_gathered'])}")
    print(f"研究结果长度: {len(result['web_research_result'][0]) if result['web_research_result'] else 0}")
    print()
    print("=== 研究结果内容 ===")
    print(result['web_research_result'][0] if result['web_research_result'] else "无结果")
    print()
    print("=== 来源信息 ===")
    for i, source in enumerate(result['sources_gathered']):
        print(f"来源 {i+1}:")
        print(f"  - 短URL: {source['short_url']}")
        print(f"  - 原URL: {source['value']}")
        print(f"  - 标题: {source.get('title', 'N/A')}")
        print()
        
except Exception as e:
    print(f"web_research函数调用失败: {e}")
    import traceback
    traceback.print_exc()
# Out:
# === 直接调用web_research函数 ===
# === web_research函数返回结果 ===
# 搜索查询: ['最新的人工智能发展趋势']
# 来源数量: 545
# 研究结果长度: 39373
#
# === 研究结果内容 ===
# Okay, I will conduct targeted Google Searches to gather the most recent, credible information on "最新的人工智能发展趋势" and synthesize it into a verifiable text artifact.
# Based on the search results, here's a summary of the latest AI development trends expected in 2025:
#
# **1. Increased Accessibili [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ty and Lower Training Costs:**
#
# *   Advancements in model architecture and hardware efficiency are significantly reducing the training costs for large-scale AI systems, making them more accessible to a wider range of users. (Source: Ultralytics  [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)[1])
# *   Lightweight AI mo [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)dels enable businesses and researchers to utilize these models without extensive computing resources, lowering the barrier to entry. (Source: Ultralytics  [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)[1])
#
# **2. AI Agents and A [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)rtific [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ial General Intelligence (AGI):**
#
# *   AI agents are becoming more advanced, bridging the gap toward AGI. Unlike traditional AI [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) systems designed for narrow tasks, these agents can continuously learn, adapt to dynamic environments, and make independent decisions based on real-time data. (Source: Ultralytics  [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)[1])
# *   Multi-agent syste [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ms, where multiple AI agents collaborate to achieve complex goals, are expected to become more prominent in 2025. These systems can opt [cac](https://vertexaisearch.cloud.google.com/id/0-5) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)imize workflows, generate insights, and assist in decision-making across various industries. (Source: Ultralytics  [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)[1])
# *   AI-driven agents  [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)will have greater autonomy to perform more tasks, improving people's quality of life. (Source: Microsoft Re [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)search [3])
#
# **3. AI for Science  [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)(AI4S) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [news](https://vertexaisearch.cloud.google.com/id/0-6) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [yicai](https://vertexaisearch.cloud.google.com/id/0-7):**
#
# *   AI4S, driven by large models, is becoming a key force in driving paradigm shifts in scientific research. (Source: 智源研究院 [4, 8] [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1))
# *   Multi-modal large models wi [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ll be further integrated into scientific research, enabling the mining of complex structures in multi-dimensional data and assisting in the comprehensive understanding and global analysis of scientific research problems. (Source: 智源研究院 [4])
# *   AI is e [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)xpected to accelerate scientif [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ic breakthroughs in sustainable materials, drug discovery, and human health. (Source: 新华网 [6], Microsoft Research [3]) [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)
#
# **4. Embodied Intelligence:**
#
# *   2025 is exp [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)ected  [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [oschina](https://vertexaisearch.cloud.google.com/id/0-10) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)to be a "元年" for embodied intelligence, with the synergistic evolution of embodied brains and bodies. (Source: 智源研究院 [4, 8])
# *   There will be more embod [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)ied intelligence applications in  [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)industrial scenarios, and some humanoid robots will be mass-produced. (Source: 智源研究院 [4])
# *   "具身智能" is a key area for future indus [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)trial development. (Source: 央视 [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)网 [11])
#
# **5. Multi-Modal AI:**
#
# *   Unified multi-modal large model [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2)s that can process data f [cac](https://vertexaisearch.cloud.google.com/id/0-5) [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)rom di [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)fferent modalities (e.g., text, images, audio, 3D) are expected to enable more efficient AI. (Source: 智源研究院 [4, 8])
# *   Native multi-modal technology, which aligns visual, audio, [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) and 3D data from the beginning o [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)f training, offers new possibilities for multi-modal development. (Source: 智源研究院 [4])
# *   Multi-modal AI will be a major driver for enterprises adopting AI, help [cac](https://vertexaisearch.cloud.google.com/id/0-5) [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ing to improve customer experi [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ence, increase operational efficiency, and develop new business models. (Source: 新华网 [6])
#
# **6. Scaling Law Expansion and Post-Training:**
#
# *   The cost-effectiveness of trainin [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)g models based on Scalin [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)g Law  [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)to improve the performance of foundation models is continuously decreasing. (Source: 智源研究院 [4])
# *   Reinforcement learning will be used more and innovatively as a key technology for disco [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)vering Scaling Laws in post-tr [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)aining and inference stages. (Source: 智源研究院 [4])
#
# **7. World Models:**
#
# *   World models that focus more on "causal" reasoning are expected to give AI [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) higher-level cognition and mo [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)re log [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [news](https://vertexaisearch.cloud.google.com/id/0-6) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ical reasoning and decision-making abilities. (Source: 智源研究院 [4])
# *   These models are expected to drive the deep application of AI in cutting-edge fields such as autonomous dri [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ving, robot control, and intel [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ligent manufacturing, and are expected to break through traditional task boundaries and explore new possibilities for human-computer interaction. (Source: 智源研究院 [4])
#
# **8. AI Security and Governance:**
#
# *   With the increasing involvement of AI in decision-making, ethical issues surroun [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)ding bias, privacy, and respon [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)sibili [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ty are becoming increasingly important. (Source: Ultralytics [1])
# *   Stricter regulations and a greater emphasis on responsible AI are expected in 2025, driving companies to develop explaina [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)ble and auditable models.  [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)(Source: Ultralytics [1])
# *   AI safety governance systems will continue to improve, with a focus on balancing model capability enhancement and risk pr [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)evention. (Source: 智源研究院 [ [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)4, 8])
#
# **9. AI-Native Applications and Super Apps:**
#
# *   The hardware carriers of large models are penetrating from the cloud to term [sina](https://vertexaisearch.cloud.google.com/id/0-2) [news](https://vertexaisearch.cloud.google.com/id/0-6) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)inal-side hardware such as mobile [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) phone [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)s and PCs. (Source: 智源研究院 [4])
# *   Algorithm acceleration and hardware optimization technologies will continue to iterate, driving the accelerated implementation of AI-Nati [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ve applications. (Source: 智源研究 [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)院 [4])
#
# **10. AI-Driven Automation and Intelligent Automation:**
#
# *   Intelligent automation is predicted to become an integral part of business processes by  [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [yicai](https://vertexaisearch.cloud.google.com/id/0-7) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)2025, enabling companies to st [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [qbitai](https://vertexaisearch.cloud.google.com/id/0-8) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)reamlin [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [news](https://vertexaisearch.cloud.google.com/id/0-6) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)e operations and improve decision-making through advanced AI capabilities. (Source: Botpress [2])
# *   Gartner identifies human-machine collaboration as a top strategic technology trend for 2025, emphasizing the integration of AI to enhance human capabiliti [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)es and improve decision [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)-making processes. (Source: Botpress [2])
#
# **11. Quantum AI:**
#
# *   Quantum AI combines quantum computing and AI to solve complex problems that traditional AI cannot handle efficiently. (Source: Botpr [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ess [2])
# *   Companies  [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)like IB [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)M and Google are investing heavily in quantum AI, indicating its potential to transform industries like healthcare, finance, and logistic [sina](https://vertexaisearch.cloud.google.com/id/0-2) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [cac](https://vertexaisearch.cloud.google.com/id/0-5)s. (Source: Botpress [2 [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)])
#
# **12. Personalized and Hyper-Personalized Experiences:**
#
# *   AI is enabling more personalized customer experiences, with companies using AI to tailor intera [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)ctions and products bas [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ed on i [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [oschina](https://vertexaisearch.cloud.google.com/id/0-10) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)ndividual preferences. (Source: Botpress [2])
# *   Industries like retail, healthcare, and finance are moving towards hyper-personalization to deepen customer engagement and build loyalty. (Source: Botpres [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)s [2])
#
# **13. AI Infras [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)tructure and Sovereign AI:**
#
# *   Continued investment in AI infrastructure and sovereign AI is expected to reshape the global technology competition landscape. (Sou [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5)rce: 第一 [poe](https://vertexaisearch.cloud.google.com/id/0-11) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)财经 [5])
# *   Sovereign AI focuses on technological autonomy, data security, and technology governance, with the core goal of ensuring that key technologies do not rely on  [sina](https://vertexaisearch.cloud.google.com/id/0-2) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [yicai](https://vertexaisearch.cloud.google.com/id/0-7) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [cac](https://vertexaisearch.cloud.google.com/id/0-5)external sources, protectin [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)g data sovereignty, and regulating the application and development of AI technologies. (Source: 第一财经 [5])
#
# **14. AI is Becoming Ubiquitous:**
#
# *   AI is no longer just a tool but an extension of human intelligence. (Source: 新浪财经 [7])
# *   AI technology is blurring the lines be [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [yicai](https://vertexaisearch.cloud.google.com/id/0-7) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)tween humans and machines,  [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)and AI  [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)will become an indispensable partner for humans, jointly exploring unknown fields. (Source: 新浪财经 [7])
#  [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)*   AI will be as ubiquitou [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)s as air. (Source: 新浪财经 [7])
#
# **15. Challenges and Considerations:**
#
# *   "Scaling Law" may face challenges due to factors such as the imminent depletion of tr [sina](https://vertexaisearch.cloud.google.com/id/0-2) [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)aining data and the surge i [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)n energy consumption and costs for la [sina](https://vertexaisearch.cloud.google.com/id/0-2) [stdaily](https://vertexaisearch.cloud.google.com/id/0-9) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)rger-scale training. (Sourc [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)e: 新华网  [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [cac](https://vertexaisearch.cloud.google.com/id/0-5)[6])
# *   The need to address ethical issues surrounding bias, privacy and responsibility as AI becomes more involved in decision-making processes. (Source: Ultralytics [1])
# *   The importance of re-shaping hu [botpress](https://vertexaisearch.cloud.google.com/id/0-1) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)man potential in the age [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1) of AI, with a focus on creativity, emotional intelligence, social skills, adaptability and lifelong learning. (Source: 第一财经 [5])
#  [wallstreet [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3)cn](https://vertexaisearch [news](https://vertexaisearch.cloud.google.com/id/0-6) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1).cloud.google.com/id/0-4) [news](https://vertexaisearch.cloud.google.com/id/0-6) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch [news](https://vertexaisearch.cloud.google.com/id/0-6) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [sina](https://vertexaisearch.cloud.google.com/id/0-2) [microsoft](https://vertexaisearch.cloud.google.com/id/0-0) [wallstreetcn](https://vertexaisearch.cloud.google.com/id/0-4) [yicai](https://vertexaisearch.cloud.google.com/id/0-7) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [botpress](https://vertexaisearch.cloud.google.com/id/0-1).cloud.google.com/id/0-0) [ultralytics](https://vertexaisearch.cloud.google.com/id/0-3) [cac](https://vertexaisearch.cloud.google.com/id/0-5) [botpress](https://vertexaisearch.cloud.google.com/id/0-1)
#
# === 来源信息 ===
# 来源 1:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 2:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 3:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 4:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 5:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 6:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 7:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 8:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 9:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 10:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 11:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 12:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 13:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 14:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 15:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 16:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 17:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 18:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 19:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 20:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 21:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 22:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 23:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 24:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 25:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 26:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 27:
# ...
#
# 来源 497:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 498:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 499:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 500:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 501:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 502:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 503:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 504:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 505:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 506:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 507:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 508:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 509:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 510:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 511:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 512:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 513:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 514:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 515:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 516:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 517:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 518:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 519:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 520:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 521:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 522:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 523:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 524:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 525:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 526:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 527:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 528:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 529:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 530:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 531:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 532:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 533:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 534:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 535:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 536:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-7
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHD08RSqXTzrmD7-jvHONqaetAMOcyOaiYSz_aamYNY5FiEBycTai6I3886VOsO59HVZwB-vEEoLLRG6wmAl1Df5bVIqMGvdsEf34aQYx2rEJd5PuGw5CKy6Hq2BTIpVZbqSA==
#   - 标题: N/A
#
# 来源 537:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 538:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A
#
# 来源 539:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-4
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXETMNaECVkdaRixIH5zKM6KI5qrJEIQbsQ7ChncCaKOK8KqCZwxXlS2pfwxA_P8PTyrSsjMbEAlr0GhY4Xi9JQlcgbmzh54j8OasX32nqDlNGAxuircfjwTuVq_E7rQFvGKU5tc
#   - 标题: N/A
#
# 来源 540:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-6
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXFZaeFyxI86IYWTnTweyNWsfn3z0R30o_ep9GlKT8e0Cf8fUhMaP-xNy6atTLc9Ws7Dq3bhFpeXo8jBVsu-RKq4GB-8DoA8LZE0UhfNAKF2Wh7NjpwSFxyszJtslSwtsWXGe9IUHazFAE4T_G43eqZXmciYXdUKsqLtYty4knATf5pPug==
#   - 标题: N/A
#
# 来源 541:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-2
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGfZgSvpgf2RFBL5h8d45oMBycKnHbaoegksjObZCEo8I6M3cElihuK6uqiQgtFnbT6iFxWfFfBncFGcga90N4vBiGp32mbfOQb-PwpmyQFAJesfJwHnzj-FmUe7nJxk_K5rov_RLgwP-3P8HtskeT_PtkWtMOAKKIbjFXQmvJse54EMb0W
#   - 标题: N/A
#
# 来源 542:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-0
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXH-mYsUutd-vp0QG5nYjPdRyMWo4fulChlN7uhEsx0G6x1ZVgEpOXdioI17DGXZ0O1As1yN9fjH3yDTwFyA7Q1FuO6rYjTt4K-C5t3_coamd86XR6uhf3604tM3Epr4w__lsQGvPNehLzltJ2Jzo2qWPua6cWSwrcuITH_XblT6Nbc=
#   - 标题: N/A
#
# 来源 543:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-3
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXERHni6M2jdcuVwiZsTx9PDWlql42cQB0kz1hQFxHgfhYFdKewpMB6knW_5GbxZlzM92Wlb7gaWMj0I39Uwsj8DKeWOo4OHmaehU_6Q1i3ixRNE_y1kXwvnfZU2VBG4RQAXEq_2OHh8pzsZgV3MfmMbGUHaBk4mtSv4Mh4eWo_de87j9LJMJsFvzVUXXDYkXV3ciGcICdvI
#   - 标题: N/A
#
# 来源 544:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-5
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHuprw9qNZ7DSCpAjBYrz7Wsi6HEHpsEC_5JNEX5bKhvqyFldn6lo6nV_-2EIWWSi25EVzc4nS3Dyi4EEzeQulIH2Pdok0_EODy26gYRTqOR3KSQ63T5TR2MnyxyKvYBZSlXcMnmieXTXhzftg-nobV67Ie
#   - 标题: N/A
#
# 来源 545:
#   - 短URL: https://vertexaisearch.cloud.google.com/id/0-1
#   - 原URL: https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE2UDqArja7KTNJmIR-2MOPcgMBuZk_vJMYmlri-kOeVs4fEJC8wyHaWTD_JWswLi2cdY5EJSr4F5FYB58_w4GlzrOQm8KIN6STIWIO1kBw3Kk0GN6JWtou-y_qM88oMhjlmi21YTUHTnY05JRYvSYnncTRxD6-D_M3yQ==
#   - 标题: N/A

# %%
# 可以修改这里测试不同的搜索查询
print("=== 测试其他搜索查询 ===")

# 测试其他查询
other_queries = [
    "Python最新版本特性",
    "OpenAI GPT-4 vs Claude",
    "机器学习算法比较"
]

for query in other_queries:
    print(f"\n--- 测试查询: {query} ---")
    
    # 格式化提示
    formatted_prompt = web_searcher_instructions.format(
        current_date=get_current_date(),
        research_topic=query,
    )
    
    try:
        response = genai_client.models.generate_content(
            model="gemini-2.0-flash-exp",
            contents=formatted_prompt,
            config={
                "tools": [{"google_search": {}}],
                "temperature": 0,
            },
        )
        
        print(f"✅ 搜索成功")
        print(f"生成文本长度: {len(response.text)}")
        
        if response.candidates and hasattr(response.candidates[0], 'grounding_metadata'):
            grounding_metadata = response.candidates[0].grounding_metadata
            if hasattr(grounding_metadata, 'grounding_chunks'):
                print(f"搜索结果数量: {len(grounding_metadata.grounding_chunks)}")
        
        # 显示前200个字符
        print(f"内容预览: {response.text[:200]}...")
        
    except Exception as e:
        print(f"❌ 搜索失败: {e}")
    
    print("-" * 40)
